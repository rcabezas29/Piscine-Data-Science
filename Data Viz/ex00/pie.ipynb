# %%
# !pip3 install SQLAlchemy

# %%
import sqlalchemy
import pandas as pd
import matplotlib.pyplot as plt

# %%
engine = sqlalchemy.create_engine('postgresql://rcabezas:mysecretpassword@localhost:5432/piscineds')

# %% [markdown]
# Count the number of items that the db has for every event_type.

# %%
df = pd.read_sql_query(sql="SELECT event_type, COUNT(*) FROM customers GROUP BY event_type", con=engine)
df
# Out:
#          event_type    count
# 0              cart  5486521
# 1          purchase  1286088
# 2  remove_from_cart  2748980
# 3              view  9654310

# %%
plt.pie(df['count'], labels=df['event_type'], autopct='%1.1f%%')
plt.show()
