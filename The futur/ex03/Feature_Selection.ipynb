# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv("../Train_knight.csv")
df['knight'] = [1 if x == 'Jedi' else 0 for x in df['knight']]
df
# Out:
#      Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0         11.800     17.26     75.26   431.9  0.09087    0.06232   0.028530
# 1         19.810     22.15    130.00  1260.0  0.09831    0.10270   0.147900
# 2         10.970     17.20     71.73   371.5  0.08915    0.11130   0.094570
# 3         11.620     18.18     76.38   408.8  0.11750    0.14830   0.102000
# 4         11.260     19.83     71.30   388.1  0.08511    0.04413   0.005067
# ..           ...       ...       ...     ...      ...        ...        ...
# 393        8.618     11.79     54.34   224.5  0.09752    0.05272   0.020610
# 394       13.530     10.94     87.91   559.2  0.12910    0.10470   0.068770
# 395       11.640     18.33     75.17   412.5  0.11420    0.10170   0.070700
# 396        9.876     19.40     63.95   298.3  0.10050    0.09697   0.061540
# 397       19.550     28.77    133.60  1207.0  0.09260    0.20630   0.178400
#
#      Prescience  Reactivity  Midi-chlorien  ...  Evade   Stims  Sprint  \
# 0      0.016380      0.1847        0.06019  ...  24.49   86.00   562.0
# 1      0.094980      0.1582        0.05395  ...  30.88  186.80  2398.0
# 2      0.036130      0.1489        0.06640  ...  26.87   90.14   476.4
# 3      0.055640      0.1957        0.07255  ...  25.40   88.14   528.1
# 4      0.005664      0.1637        0.06343  ...  26.43   76.38   435.9
# ..          ...         ...            ...  ...    ...     ...     ...
# 393    0.007799      0.1683        0.07187  ...  15.40   59.90   274.9
# 394    0.065560      0.2403        0.06641  ...  12.49   91.36   605.5
# 395    0.034850      0.1801        0.06520  ...  29.26   85.51   521.7
# 396    0.030290      0.1945        0.06322  ...  26.83   72.22   361.2
# 397    0.114400      0.1893        0.06232  ...  36.27  178.60  1926.0
#
#       Combo    Delay  Attunement  Empowered   Burst  Grasping  knight
# 0    0.1244  0.17260     0.14490    0.05356  0.2779   0.08121       0
# 1    0.1512  0.31500     0.53720    0.23880  0.2768   0.07615       1
# 2    0.1391  0.40820     0.47790    0.15550  0.2540   0.09532       0
# 3    0.1780  0.28780     0.31860    0.14160  0.2660   0.09270       0
# 4    0.1108  0.07723     0.02533    0.02832  0.2557   0.07613       0
# ..      ...      ...         ...        ...     ...       ...     ...
# 393  0.1733  0.12390     0.11680    0.04419  0.3220   0.09026       0
# 394  0.1451  0.13790     0.08539    0.07407  0.2710   0.07191       0
# 395  0.1688  0.26600     0.28730    0.12180  0.2806   0.09097       0
# 396  0.1559  0.23020     0.26440    0.09749  0.2622   0.08490       0
# 397  0.1281  0.53290     0.42510    0.19410  0.2818   0.10050       1
#
# [398 rows x 31 columns]

# %%
for col in df:
	try:
		df[col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min
if_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(len(df.columns))]
vif_data["Tolerance"] = 1 / vif_data["VIF"]
vif_data.sort_values(by='VIF', ascending=False)
# Out:
#           feature           VIF  Tolerance
# 2        Strength  23234.851305   0.000043
# 0     Sensitivity  22412.113908   0.000045
# 20       Recovery   3223.566457   0.000310
# 22          Stims   1404.917613   0.000712
# 3           Power   1057.507872   0.000946
# 23         Sprint    946.918518   0.001056
# 5       Dexterity    175.773919   0.005689
# 10          Slash    166.111511   0.006020
# 6       Awareness    160.015784   0.006249
# 12           Pull    149.596478   0.006685
# 27      Empowered    149.386205   0.006694
# 7      Prescience    145.718276   0.006863
# 25          Delay    109.827991   0.009105
# 21          Evade    107.639792   0.009290
# 26     Attunement     89.938664   0.011119
# 24          Combo     77.250876   0.012945
# 13     Lightsaber     70.754077   0.014133
# 29       Grasping     69.554649   0.014377
# 1        Hability     69.152484   0.014461
# 17       Blocking     68.553733   0.014587
# 28          Burst     54.168123   0.018461
# 9   Midi-chlorien     51.541632   0.019402
# 4         Agility     45.878883   0.021797
# 15        Repulse     42.127725   0.023737
# 16     Friendship     38.569233   0.025927
# 8      Reactivity     34.256672   0.029191
# 19           Mass     22.896178   0.043675
# 18     Deflection     17.080745   0.058545
# 14       Survival     15.496766   0.064530
# 11           Push     13.803008   0.072448
# 30         knight      7.015453   0.142542

# %%
def calculate_vifs(dataframe):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = dataframe.columns
    vif_data["VIF"] = [variance_inflation_factor(dataframe.values, i) for i in range(dataframe.shape[1])]
    return vif_data

while True:
    vif_data = calculate_vifs(df)
    max_vif = vif_data['VIF'].max()
    if max_vif > 5:
        max_vif_column = vif_data.loc[vif_data['VIF'] == max_vif, 'Feature'].values[0]
        df = df.drop(columns=[max_vif_column])
    else:
        break

vif_data["Tolerance"] = 1 / vif_data["VIF"]
# Out:
# Removing Strength with VIF = 23234.85130549126
# Removing Recovery with VIF = 3116.3553666020057
# Removing Sensitivity with VIF = 1058.642580154316
# Removing Stims with VIF = 335.9569308195557
# Removing Awareness with VIF = 146.35501607834397
# Removing Empowered with VIF = 131.25746622078498
# Removing Evade with VIF = 98.02833596483303
# Removing Delay with VIF = 90.31385560226752
# Removing Slash with VIF = 74.06701292588997
# Removing Combo with VIF = 60.575160066350264
# Removing Dexterity with VIF = 59.724610518609424
# Removing Sprint with VIF = 50.53193822159013
# Removing Grasping with VIF = 47.96388677401536
# Removing Pull with VIF = 35.015398837938974
# Removing Prescience with VIF = 30.460355814860762
# Removing Reactivity with VIF = 25.868409722310766
# Removing Attunement with VIF = 21.660101095484613
# Removing Midi-chlorien with VIF = 20.36564834641985
# Removing Blocking with VIF = 18.671356483049188
# Removing Repulse with VIF = 11.641543839957336
# Removing Burst with VIF = 11.051599564598295
# Removing Power with VIF = 10.055254951467143
# Removing Hability with VIF = 6.470081394147761
# Removing Agility with VIF = 6.099400548334027
# Removing Mass with VIF = 5.909349243276803

# %%
vif_data
# Out:
#       Feature       VIF  Tolerance
# 0        Push  3.908117   0.255878
# 1  Lightsaber  2.132642   0.468902
# 2    Survival  4.602620   0.217268
# 3  Friendship  2.438340   0.410115
# 4  Deflection  4.833828   0.206875
# 5      knight  2.129269   0.469645
